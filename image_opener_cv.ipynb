# %%
# !pip install -U gif2numpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gif2numpy: filename=gif2numpy-1.3-py2.py3-none-any.whl size=8391 sha256=508725ebb3ec5cf5a21bbc98be1f7440e2fc4fe30d4b14d8c8949d44caa949c9
#   Stored in directory: /root/.cache/pip/wheels/cc/fe/e7/91267ab1e4bedcebf7c50568accd71a0d8117b6b8d92a1a536
# Successfully built gif2numpy
# ...

# %%
from google.colab import files
from google.colab.patches import cv2_imshow
import gif2numpy as gf
import cv2 as cv

def show_image(file_name):
    #get the uploaded file name and ensure it's an image with the correct extension
    if not file_name.endswith(('.png', '.jpg', '.jpeg', '.bmp')):
        print(f"Error: Unsupported image format. Please upload a PNG, JPEG, BMP, or GIF image.")
        exit()

    #read the image using OpenCV
    image = cv.imread(file_name)

    #check if image is read successfully
    if image is None:
        print(f"Error: Could not read image {file_name}.")
        exit()

    #display the image
    cv2_imshow(image)
    cv.waitKey(0)
    cv.destroyAllWindows()
    print("Image opened successfully!")

def show_video(file_name):
    #get the uploaded file name and ensure it's an image with the correct extension
    if not file_name.endswith(('.gif')):
        print(f"Error: Unsupported image format. Please upload a PNG, JPEG, BMP, or GIF image.")
        exit()

    #read the video using OpenCV and Gif2Numpy
    frames, exts, image_specs = gf.convert(file_name)

    #display the video
    for i in range(len(frames)):
        cv2_imshow(frames[i])
        cv.waitKey(0)
    cv.destroyAllWindows()

    print("GIF opened successfully!")

# %%
#upload an image: PNG
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
show_image(file_name)
# Out:
#      <input type="file" id="files-5b840838-5b1a-4e53-bdbd-5a33b88e7d81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b840838-5b1a-4e53-bdbd-5a33b88e7d81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload an image: JPG
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
show_image(file_name)
# Out:
#      <input type="file" id="files-5a4ce110-b8b9-4539-b9af-c05b3dfc9a7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a4ce110-b8b9-4539-b9af-c05b3dfc9a7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload an image: BMP
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
show_image(file_name)
# Out:
#      <input type="file" id="files-c3bb8d72-9739-4f96-91ae-ebf5cb7030d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3bb8d72-9739-4f96-91ae-ebf5cb7030d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#upload an image: GIF
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
show_video(file_name)
# Out:
#      <input type="file" id="files-eef13f9e-f9b5-4b0a-ae3a-f073ead34501" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eef13f9e-f9b5-4b0a-ae3a-f073ead34501">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
